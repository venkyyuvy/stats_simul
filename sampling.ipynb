# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 100000
variance = 1000000
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.figure(figsize=(15, 4))
plt.plot(x, stats.norm.pdf(x, mu, sigma), color='tab:orange')
plt.axvline(mu, color='tab:grey')

# sampling distribution
rng = np.random.RandomState(None)
n_samples = 3000
sample_size = 30
sample_means = np.array([np.mean(rng.normal(mu, sigma, size= sample_size)) 
                for _ in range(n_samples)])
sample_means.sort()
density =  stats.norm.pdf(sample_means, sample_means.mean(), sample_means.std(),)
plt.plot(sample_means, density ,  color='tab:blue')
plt.fill_between(sample_means, density,  color='blue', alpha=.2)
# type I error

lb = sample_means.mean() + stats.norm.ppf(0.005) * (sample_means.std())
plt.axvline(lb, color='violet')
ub = sample_means.mean() - stats.norm.ppf(0.005) * (sample_means.std())
plt.axvline(ub, color='violet')

# null hypothesis

mu_0 = 99200
plt.axvline(mu_0, color='tab:red')
x = np.linspace(mu_0 - 3*sigma/np.sqrt(sample_size), 
                mu_0 + 3*sigma/np.sqrt(sample_size), 100)
density = stats.norm.pdf(x, mu_0, sigma/np.sqrt(sample_size))
plt.fill_between(x, density, color='tab:red', alpha=0.2)

# # type II error
# lb = mu_0 + stats.norm.ppf(0.005) * (sample_means.std())
# plt.axvline(lb, color='red')
# ub = mu_0 - stats.norm.ppf(0.005) * (sample_means.std())
# plt.axvline(ub, color='red')

# %%
sigma/np.sqrt(sample_size)
# Out:
# 141.4213562373095

# %%
sample_means.std()
# Out:
# 142.20787195101025

# %%
sample_means[100]
# Out:
# 98966.90287876868

# %%
mu = 24332
variance = 12233
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.figure(figsize=(15, 4))
plt.plot(x, stats.norm.pdf(x, mu, sigma), color='tab:orange')
plt.axvline(mu, color='tab:grey')

# %%
normalized = (x - mu)/sigma

normalized = (x - mu)/sigma
f'{normalized.mean():.3f}'
f'{normalized.std():.3f}'
# Out:
# '1.749'

# %%
normalized = (x - mu)/sigma
plt.figure(figsize=(15, 4))
plt.plot(normalized, stats.norm.pdf(normalized, mu, sigma), color='tab:orange')
plt.axvline(mu, color='tab:grey')
# Out:
# array([-3.        , -2.93939394, -2.87878788, -2.81818182, -2.75757576,
#        -2.6969697 , -2.63636364, -2.57575758, -2.51515152, -2.45454545,
#        -2.39393939, -2.33333333, -2.27272727, -2.21212121, -2.15151515,
#        -2.09090909, -2.03030303, -1.96969697, -1.90909091, -1.84848485,
#        -1.78787879, -1.72727273, -1.66666667, -1.60606061, -1.54545455,
#        -1.48484848, -1.42424242, -1.36363636, -1.3030303 , -1.24242424,
#        -1.18181818, -1.12121212, -1.06060606, -1.        , -0.93939394,
#        -0.87878788, -0.81818182, -0.75757576, -0.6969697 , -0.63636364,
#        -0.57575758, -0.51515152, -0.45454545, -0.39393939, -0.33333333,
#        -0.27272727, -0.21212121, -0.15151515, -0.09090909, -0.03030303,
#         0.03030303,  0.09090909,  0.15151515,  0.21212121,  0.27272727,
#         0.33333333,  0.39393939,  0.45454545,  0.51515152,  0.57575758,
#         0.63636364,  0.6969697 ,  0.75757576,  0.81818182,  0.87878788,
# ...

# %% [markdown]
# - two tailed test
# - variance - 1 for standard normal distribution (Z)
# - example problems to try out - z test
# - tools for z-test
